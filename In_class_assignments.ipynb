# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanknapp123/first-repository/blob/main/In_class_assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignment number one
#sales input
sales= float(input("enter the sales of the company"))
cogs=.4*sales
profit=sales-cogs
tax= float(input("enter the tax rate in percent"))
tax_total=profit*tax/100
Net_income=profit-tax_total
print(cogs)
print("the profit of the company is", profit)
print("the Net Income of the company is", Net_income)
# Out:
# enter the sales of the company12000
# enter the tax rate in percent30
# 4800.0
# the profit of the company is 7200.0
# the Net Income of the company is 5040.0

# %%
#Assignment number two
num_1=int(input("enter the first number"))
num_2=int(input("enter the second number"))
op_1=input("enter the operator")
if op_1=="+":
    print(num_1+num_2)
elif op_1=="-":
  print(num_1-num_2)
elif op_1=="*":
  print(num_1*num_2)
elif op_1=="/":
  print(num_1/num_2)
elif op_1=="//":
  print(num_1//num_2)
elif op_1=="**":
  print(num_1**num_2)
elif op_1=="%":
  print(num_1%num_2)
else:
  print("invalid operator")
# Out:
# enter the first number3
# enter the second number2
# enter the operator**
# 9

# %%
# Out:
# 0.0
# 0
# 5.0
# 75
# 7.0710678118654755
# 90
# 8.660254037844387
# 105
# 10.0
# 100
# 11.180339887498949
# 95
# 12.24744871391589
# 90
# 13.228756555322953
# 85
# 14.142135623730951
# 80

# %%
#assignment 3
fee=2.5
flat_rate=5
total_charge=0
n=0
while n<=8:
  hours=int(input("enter the number of hours you were parked for. the max park time is 8 hours"))
  n=hours
  if n>0 and n<=8:
    cost=fee*n+flat_rate
    print("your fee is",cost,"hours parked=",n)
    total_charge+=cost
    if total_charge > 20:
      total_charge = 20
      print("Maximum charge of $20 reached. Final total charge:", total_charge)
      break
    elif total_charge <= 10:
      total_charge = 10
      print("Total charge set to minimum of $10. Final total charge:", total_charge)
      break
  elif n==0:
    print("No hours entered. Exiting.")
    break
  else:
    print("Invalid hours. Max park time is 8 hours. Please try again.")
# Out:
# enter the number of hours you were parked for. the max park time is 8 hours0
# No hours entered. Exiting.

# %%
import math
ticket=10
init_attendees = 20
fixed_cost=200
for ad in range(0,201,25):
  rev=(init_attendees+ 2* round(math.sqrt(ad)))*ticket
  cost= fixed_cost+ad
  profit=rev-cost
  print(profit)
# Out:
# 0
# 75
# 90
# 105
# 100
# 95
# 90
# 85
# 80

# %%
import math
ticket=10
init_attendees = 20
fixed_cost=200

ad = 0
while ad <= 200:
  rev=(init_attendees+ 2* round(math.sqrt(ad)))*ticket
  cost= fixed_cost+ad
  profit=rev-cost
  print(profit)
  ad += 25
